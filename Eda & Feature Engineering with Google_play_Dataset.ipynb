# %% [markdown]
# ## EDA with googleplaystore_data

# %% [markdown]
# ## import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # read the csv data

# %%
df = pd.read_csv(r'E:\himanshu_2022\Download\googleplaystore.csv')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
# show only 5 rows in this df...
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# show last 5 row...
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
# generate random sample of the data...
df.sample(10)
# Out:
#                                                     App            Category  \
# 3418                       Galactic Core Free Wallpaper     PERSONALIZATION
# 9732  Multi Surgery ER Emergency Hospital : Doctor Game              FAMILY
# 6111         Hot Bhojpuri Video Song 2018 - Free Movies              FAMILY
# 7096                                            Save.ca            SHOPPING
# 1054                                      Nedbank Money             FINANCE
# 1157                                BankMobile Vibe App             FINANCE
# 1233      Postmates Food Delivery: Order Eats & Alcohol      FOOD_AND_DRINK
# 367                                   WhatsApp Business       COMMUNICATION
# 6541                                  BN Pro White Text  LIBRARIES_AND_DEMO
# 8223                                      DB FahrtProfi    TRAVEL_AND_LOCAL
#
#       Rating Reviews  Size     Installs  Type Price Content Rating  \
# ...

# %%
# information about df....
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# # Data cleaning

# %%
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# # statistics data..

# %%
df.describe(include = 'all').T
# Out:
#                  count unique                 top   freq      mean       std  \
# App              10841   9660              ROBLOX      9       NaN       NaN
# Category         10841     34              FAMILY   1972       NaN       NaN
# Rating          9367.0    NaN                 NaN    NaN  4.193338  0.537431
# Reviews          10841   6002                   0    596       NaN       NaN
# Size             10841    462  Varies with device   1695       NaN       NaN
# Installs         10841     22          1,000,000+   1579       NaN       NaN
# Type             10840      3                Free  10039       NaN       NaN
# Price            10841     93                   0  10040       NaN       NaN
# Content Rating   10840      6            Everyone   8714       NaN       NaN
# Genres           10841    120               Tools    842       NaN       NaN
# Last Updated     10841   1378      August 3, 2018    326       NaN       NaN
# ...

# %%
## check shape the data...
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
## about Reviews columns...
df['Reviews'].head()
# Out:
# 0       159
# 1       967
# 2     87510
# 3    215644
# 4       967
# Name: Reviews, dtype: object

# %%
## check the other values also...
df['Reviews'].shape
# Out:
# (10841,)

# %%
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
## check numeric values...
df.Reviews.str.isnumeric().sum()
# Out:
# 10840

# %%
~df['Reviews'].str.isnumeric()
## wherever we have numeric value it is giving reverse.
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Reviews, Length: 10841, dtype: bool

# %%
df[~df['Reviews'].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
## know we drop this row ...

# %%
## inside that we store it new variable...
df_copy = df.copy()

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
## drop the data with index 10472...
df_copy = df_copy.drop(df_copy.index[10472])

# %%
df_copy.shape
# Out:
# (10840, 13)

# %%
df['Reviews'].dtype
# Out:
# dtype('O')

# %%
# change the datatype this columns...
df_copy["Reviews"]=df_copy["Reviews"].astype('int')

# %%
df_copy["Reviews"].dtype
# Out:
# dtype('int32')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int32
#  4   Size            10840 non-null  object
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int32(1), object(11)
# memory usage: 1.1+ MB

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# # check the unique values..

# %%
df_copy['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
df_copy["Size"]=df_copy["Size"].str.replace('M','000')

# %%
df_copy['Size']
# Out:
# 0                     19000
# 1                     14000
# 2                    8.7000
# 3                     25000
# 4                    2.8000
#                 ...
# 10836                 53000
# 10837                3.6000
# 10838                9.5000
# 10839    Varies with device
# 10840                 19000
# Name: Size, Length: 10840, dtype: object

# %%
df_copy["Size"]=df_copy["Size"].str.replace('k','')

# %%
df_copy["Size"].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', 'Varies with device', '9.4000', '15000', '10000',
#        '1.2000', '26000', '8.0000', '7.9000', '56000', '57000', '35000',
#        '54000', '201', '3.6000', '5.7000', '8.6000', '2.4000', '27000',
#        '2.5000', '16000', '3.4000', '8.9000', '3.9000', '2.9000', '38000',
#        '32000', '5.4000', '18000', '1.1000', '2.2000', '4.5000', '9.8000',
#        '52000', '9.0000', '6.7000', '30000', '2.6000', '7.1000', '3.7000',
#        '22000', '7.4000', '6.4000', '3.2000', '8.2000', '9.9000',
#        '4.9000', '9.5000', '5.0000', '5.9000', '13000', '73000', '6.8000',
#        '3.5000', '4.0000', '2.3000', '7.2000', '2.1000', '42000',
# ...

# %%
import numpy as np

# %%
np.nan
# Out:
# nan

# %%
df_copy["Size"]=df_copy["Size"].str.replace("Varies with device", str(np.nan))

# %%
df_copy["Size"].dtype
# Out:
# dtype('O')

# %%
## change the datatypes in float .....
df_copy['Size']=df_copy["Size"].astype("float")

# %%
df_copy['Size'].head()
# Out:
# 0    19000.0
# 1    14000.0
# 2        8.7
# 3    25000.0
# 4        2.8
# Name: Size, dtype: float64

# %%
# this index less values..
df_copy["Size"][2]*1000
# Out:
# 8700.0

# %%
# we can iterate it ....
for i in df_copy['Size']:
    if i < 10:
        df_copy['Size']=df_copy['Size'].replace(i,i*1000)

# %%
df_copy['Size'].head()
# Out:
# 0    19000.0
# 1    14000.0
# 2     8700.0
# 3    25000.0
# 4     2800.0
# Name: Size, dtype: float64

# %%
df_copy["Size"].unique()
# Out:
# array([1.90e+04, 1.40e+04, 8.70e+03, 2.50e+04, 2.80e+03, 5.60e+03,
#        2.90e+04, 3.30e+04, 3.10e+03, 2.80e+04, 1.20e+04, 2.00e+04,
#        2.10e+04, 3.70e+04, 2.70e+03, 5.50e+03, 1.70e+04, 3.90e+04,
#        3.10e+04, 4.20e+03, 7.00e+03, 2.30e+04, 6.00e+03, 6.10e+03,
#        4.60e+03, 9.20e+03, 5.20e+03, 1.10e+04, 2.40e+04,      nan,
#        9.40e+03, 1.50e+04, 1.00e+04, 1.20e+03, 2.60e+04, 8.00e+03,
#        7.90e+03, 5.60e+04, 5.70e+04, 3.50e+04, 5.40e+04, 2.01e+02,
#        3.60e+03, 5.70e+03, 8.60e+03, 2.40e+03, 2.70e+04, 2.50e+03,
#        1.60e+04, 3.40e+03, 8.90e+03, 3.90e+03, 2.90e+03, 3.80e+04,
#        3.20e+04, 5.40e+03, 1.80e+04, 1.10e+03, 2.20e+03, 4.50e+03,
#        9.80e+03, 5.20e+04, 9.00e+03, 6.70e+03, 3.00e+04, 2.60e+03,
#        7.10e+03, 3.70e+03, 2.20e+04, 7.40e+03, 6.40e+03, 3.20e+03,
#        8.20e+03, 9.90e+03, 4.90e+03, 9.50e+03, 5.00e+03, 5.90e+03,
#        1.30e+04, 7.30e+04, 6.80e+03, 3.50e+03, 4.00e+03, 2.30e+03,
# ...

# %%
df_copy["Size"]=df_copy["Size"]/1000

# %%
df_copy["Size"].unique()
# Out:
# array([1.90e+01, 1.40e+01, 8.70e+00, 2.50e+01, 2.80e+00, 5.60e+00,
#        2.90e+01, 3.30e+01, 3.10e+00, 2.80e+01, 1.20e+01, 2.00e+01,
#        2.10e+01, 3.70e+01, 2.70e+00, 5.50e+00, 1.70e+01, 3.90e+01,
#        3.10e+01, 4.20e+00, 7.00e+00, 2.30e+01, 6.00e+00, 6.10e+00,
#        4.60e+00, 9.20e+00, 5.20e+00, 1.10e+01, 2.40e+01,      nan,
#        9.40e+00, 1.50e+01, 1.00e+01, 1.20e+00, 2.60e+01, 8.00e+00,
#        7.90e+00, 5.60e+01, 5.70e+01, 3.50e+01, 5.40e+01, 2.01e-01,
#        3.60e+00, 5.70e+00, 8.60e+00, 2.40e+00, 2.70e+01, 2.50e+00,
#        1.60e+01, 3.40e+00, 8.90e+00, 3.90e+00, 2.90e+00, 3.80e+01,
#        3.20e+01, 5.40e+00, 1.80e+01, 1.10e+00, 2.20e+00, 4.50e+00,
#        9.80e+00, 5.20e+01, 9.00e+00, 6.70e+00, 3.00e+01, 2.60e+00,
#        7.10e+00, 3.70e+00, 2.20e+01, 7.40e+00, 6.40e+00, 3.20e+00,
#        8.20e+00, 9.90e+00, 4.90e+00, 9.50e+00, 5.00e+00, 5.90e+00,
#        1.30e+01, 7.30e+01, 6.80e+00, 3.50e+00, 4.00e+00, 2.30e+00,
# ...

# %%
## check the columns...
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_copy.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159  19.0   10,000+  Free     0       Everyone
# 1      967  14.0  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
## check the Installs columns...
df_copy['Installs'].dtype
# Out:
# dtype('O')

# %%
## check the unique value this columns...
# and remove the + sign ..
df_copy['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
## check the price columns...
df_copy["Price"].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
## handle these two columns..

# %%
chars_to_remove=['+',',','$']
cols_to_clean=['Installs',"Price"]
for item in chars_to_remove:
    for col in cols_to_clean:
        df_copy[col]=df_copy[col].str.replace(item,'')

# %%
df_copy["Price"].unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df_copy["Installs"].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0'], dtype=object)

# %%
df_copy["Installs"]=df_copy["Installs"].astype('int')

# %%
df_copy["Price"]=df_copy["Price"].astype('float')

# %%
# last conclusions...

# %%
df_copy.describe()
# Out:
#             Rating       Reviews         Size      Installs         Price
# count  9366.000000  1.084000e+04  9145.000000  1.084000e+04  10840.000000
# mean      4.191757  4.441529e+05    21.506534  1.546434e+07      1.027368
# std       0.515219  2.927761e+06    22.596021  8.502936e+07     15.949703
# min       1.000000  0.000000e+00     0.010000  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01     4.900000  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03    13.000000  1.000000e+05      0.000000
# 75%       4.500000  5.477550e+04    30.000000  5.000000e+06      0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09    400.000000

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# check this columns...
df_copy["Last Updated"]
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10840, dtype: object

# %%
## sepearete this columns....

# %%
# check this columns datatype...
df_copy["Last Updated"].dtype
# Out:
# dtype('O')

# %%
## convert into date time ....
df_copy["Last Updated"]=pd.to_datetime(df_copy["Last Updated"])

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
## segrgate the day ....
df_copy["day"]=df_copy["Last Updated"].dt.day

# %%
# month...
df_copy["month"]=df_copy["Last Updated"].dt.month

# %%
# year...
df_copy["year"]=df_copy["Last Updated"].dt.year

# %%
df_copy.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# save the data...
df_copy.to_csv("google_cleaned.csv",index=False)

# %% [markdown]
# # After cleaned_csv data some more EDA & feature engineering......

# %% [markdown]
# # read the data...

# %%
# now its our clean dataset...
df1 = pd.read_csv("google_cleaned.csv")

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
pd.read_csv("google_cleaned.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
# show only top 5 rows...
df1.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159  19.0     10000  Free    0.0       Everyone
# 1      967  14.0    500000  Free    0.0       Everyone
# 2    87510   8.7   5000000  Free    0.0       Everyone
# 3   215644  25.0  50000000  Free    0.0           Teen
# 4      967   2.8    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
# show only 5 last rows..
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
# shape of the data...
df1.shape
# Out:
# (10840, 16)

# %%
# random sample of the data...
df1.sample(5)
# Out:
#                                               App           Category  Rating  \
# 7380                                 CI Staff App          LIFESTYLE     NaN
# 1765                                   Wordscapes               GAME     4.8
# 88    AutoScout24 Switzerland – Find your new car  AUTO_AND_VEHICLES     4.6
# 5768                                Amber Weather            WEATHER     4.4
# 9105                             Météo Algérie DZ            WEATHER     4.1
#
#       Reviews  Size  Installs  Type  Price Content Rating           Genres  \
# 7380        0  10.0        10  Free    0.0       Everyone        Lifestyle
# 1765   230727  87.0  10000000  Free    0.0       Everyone             Word
# 88      13372   NaN   1000000  Free    0.0       Everyone  Auto & Vehicles
# 5768   260137  13.0  10000000  Free    0.0   Everyone 10+          Weather
# 9105     1238   4.7    100000  Free    0.0       Everyone          Weather
#
# ...

# %%
# information about the df...
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10840 entries, 0 to 10839
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
#  13  day             10840 non-null  int64
#  14  month           10840 non-null  int64
#  15  year            10840 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
# check the null values....
df1.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size              1695
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# day                  0
# month                0
# year                 0
# dtype: int64

# %% [markdown]
# # statistics data......

# %%
df1.describe().T
# Out:
#             count          mean           std      min     25%       50%  \
# Rating     9366.0  4.191757e+00  5.152189e-01     1.00     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06     0.00    38.0    2094.0
# Size       9145.0  2.150653e+01  2.259602e+01     0.01     4.9      13.0
# Installs  10840.0  1.546434e+07  8.502936e+07     0.00  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01     0.00     0.0       0.0
# day       10840.0  1.560904e+01  9.561621e+00     1.00     6.0      16.0
# month     10840.0  6.422325e+00  2.578388e+00     1.00     5.0       7.0
# year      10840.0  2.017400e+03  1.100914e+00  2010.00  2017.0    2018.0
#
#                 75%           max
# Rating          4.5  5.000000e+00
# Reviews     54775.5  7.815831e+07
# Size           30.0  1.000000e+02
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02
# day            24.0  3.100000e+01
# month           8.0  1.200000e+01
# ...

# %%
# information all the describe data....
df1.describe(include='all')
# Out:
#            App Category       Rating       Reviews         Size      Installs  \
# count    10840    10840  9366.000000  1.084000e+04  9145.000000  1.084000e+04
# unique    9659       33          NaN           NaN          NaN           NaN
# top     ROBLOX   FAMILY          NaN           NaN          NaN           NaN
# freq         9     1972          NaN           NaN          NaN           NaN
# mean       NaN      NaN     4.191757  4.441529e+05    21.506534  1.546434e+07
# std        NaN      NaN     0.515219  2.927761e+06    22.596021  8.502936e+07
# min        NaN      NaN     1.000000  0.000000e+00     0.010000  0.000000e+00
# 25%        NaN      NaN     4.000000  3.800000e+01     4.900000  1.000000e+03
# 50%        NaN      NaN     4.300000  2.094000e+03    13.000000  1.000000e+05
# 75%        NaN      NaN     4.500000  5.477550e+04    30.000000  5.000000e+06
# max        NaN      NaN     5.000000  7.815831e+07   100.000000  1.000000e+09
#
# ...

# %%
## entire sum of null values...
df1.isnull().sum().sum()
# Out:
# 3180

# %% [markdown]
# # duplicate value in data...

# %%
df1.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10835    False
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# Length: 10840, dtype: bool

# %%
## how many duplicated rows in dataset...
df1[df1.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10767                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df1 = df1.drop_duplicates()

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df1.shape
# Out:
# (10357, 16)

# %%
## example how to check duplicate values...
l1 = [1,2,10,11,3,3,3,4,4,5,5,5,5]

# %%
dff = pd.DataFrame(l1)

# %%
dff[dff.duplicated()]
# Out:
#     0
# 5   3
# 6   3
# 8   4
# 10  5
# 11  5
# 12  5

# %%
## drop duplicates values... 
dff.drop_duplicates()
# Out:
#     0
# 0   1
# 1   2
# 2  10
# 3  11
# 4   3
# 7   4
# 9   5

# %% [markdown]
# # Exploring the data

# %% [markdown]
# # segregate the cat  and num feature

# %%
df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
numeric_features = [feature for feature in df1.columns if df1[feature].dtype != 'O']
categorical_features = [feature for feature in df1.columns if df1[feature].dtype == 'O']

# %%
numeric_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
num_df1 = df1[numeric_features]

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %% [markdown]
# # counts the categorical features...

# %%
cat_df1 = df1[categorical_features]

# %%
# count the  APP columns...
df1['App'].value_counts()
# Out:
# ROBLOX                                           9
# 8 Ball Pool                                      7
# Bubble Shooter                                   6
# Helix Jump                                       6
# Zombie Catchers                                  6
#                                                 ..
# Popsicle Launcher for Android P 9.0 launcher     1
# PixelLab - Text on pictures                      1
# P Launcher for Android™ 9.0                      1
# Pacify (Android P theme) - Theme for Xperia™     1
# iHoroscope - 2018 Daily Horoscope & Astrology    1
# Name: App, Length: 9659, dtype: int64

# %%
# check how many category ...
len(df1['App'].value_counts())
# Out:
# 9659

# %%
# check in percentage...
df1['App'].value_counts(normalize=True)
# Out:
# ROBLOX                                           0.000869
# 8 Ball Pool                                      0.000676
# Bubble Shooter                                   0.000579
# Helix Jump                                       0.000579
# Zombie Catchers                                  0.000579
#                                                    ...
# Popsicle Launcher for Android P 9.0 launcher     0.000097
# PixelLab - Text on pictures                      0.000097
# P Launcher for Android™ 9.0                      0.000097
# Pacify (Android P theme) - Theme for Xperia™     0.000097
# iHoroscope - 2018 Daily Horoscope & Astrology    0.000097
# Name: App, Length: 9659, dtype: float64

# %%
num_df1
# Out:
#        Rating  Reviews  Size  Installs  Price  day  month  year
# 0         4.1      159  19.0     10000    0.0    7      1  2018
# 1         3.9      967  14.0    500000    0.0   15      1  2018
# 2         4.7    87510   8.7   5000000    0.0    1      8  2018
# 3         4.5   215644  25.0  50000000    0.0    8      6  2018
# 4         4.3      967   2.8    100000    0.0   20      6  2018
# ...       ...      ...   ...       ...    ...  ...    ...   ...
# 10835     4.5       38  53.0      5000    0.0   25      7  2017
# 10836     5.0        4   3.6       100    0.0    6      7  2018
# 10837     NaN        3   9.5      1000    0.0   20      1  2017
# 10838     4.5      114   NaN      1000    0.0   19      1  2015
# 10839     4.5   398307  19.0  10000000    0.0   25      7  2018
#
# [10357 rows x 8 columns]

# %%
## check the distribution  of the numerical variable....
sns.kdeplot(num_df1['Rating'])
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
## check the distribution entire variable...
for feature in numeric_features:
    sns.kdeplot(num_df1[feature])
    plt.xlabel(feature)
    plt.ylabel('counts')
    plt.title('Numerical features')
    plt.show()

# %%
plt.figure(figsize=(15,15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20 ,fontweight='bold',alpha=0.8,y=1.)

for i in range(0,len(numeric_features)):
    plt.subplot(5,3,i+1)
    sns.kdeplot(x=df1[numeric_features[i]],shade=True,color='r')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
## distribution with categorical variable....
cat_df1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10835                                   Sya9a Maroc - FR               FAMILY
# 10836                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                             Parkinson Exercices FR              MEDICAL
# 10838                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
## check counts  Type the cate.. variable...
cat_df1['Type'].value_counts()
# Out:
# Free    9591
# Paid     765
# Name: Type, dtype: int64

# %%
sns.countplot(cat_df1['Type'])
# Out:
# <AxesSubplot:xlabel='Type', ylabel='count'>

# %%
sns.countplot(cat_df1['Content Rating'])
# Out:
# <AxesSubplot:xlabel='Content Rating', ylabel='count'>

# %%
## categorical columns...
plt.figure(figsize=(40,35))
plt.suptitle('Univariate Analysis of Categorical features',fontsize=20,fontweight='bold',alpha=0.8,y=1.)
category = ['Type' ,'Content Rating','Category']
for i in range(0, len(category)):
    plt.subplot(2,2,i+1)
    sns.countplot(x= df1[category[i]],palette='Set2')
    plt.xlabel(category[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %% [markdown]
# # which one will be a  most popular category ?

# %%
cat_df1['Category'].value_counts().plot.pie(figsize=(20,20),autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
# store in dataframe ...
category = pd.DataFrame(cat_df1['Category'].value_counts())

# %%
category.head(10)
# Out:
#                  Category
# FAMILY               1943
# GAME                 1121
# TOOLS                 843
# BUSINESS              427
# MEDICAL               408
# PRODUCTIVITY          407
# PERSONALIZATION       388
# LIFESTYLE             373
# COMMUNICATION         366
# FINANCE               360

# %%
## rename the particular columns...
category.rename(columns={"Category":"Count"},inplace=True)

# %%
category.head(10)
# Out:
#                  Count
# FAMILY            1943
# GAME              1121
# TOOLS              843
# BUSINESS           427
# MEDICAL            408
# PRODUCTIVITY       407
# PERSONALIZATION    388
# LIFESTYLE          373
# COMMUNICATION      366
# FINANCE            360

# %%
sns.countplot(category['Count'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='count'>

# %%
# countplot...
plt.figure(figsize=(20,20))
sns.barplot(x=category.index[:10],y= "Count",data=category[:10])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
cat_df1.head()
# Out:
#                                                  App        Category  Type  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN  Free
# 1                                Coloring book moana  ART_AND_DESIGN  Free
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN  Free
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN  Free
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN  Free
#
#   Content Rating                     Genres Last Updated         Current Ver  \
# 0       Everyone               Art & Design   2018-01-07               1.0.0
# 1       Everyone  Art & Design;Pretend Play   2018-01-15               2.0.0
# 2       Everyone               Art & Design   2018-08-01               1.2.4
# 3           Teen               Art & Design   2018-06-08  Varies with device
# 4       Everyone    Art & Design;Creativity   2018-06-20                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# ...

# %%
num_df1.head()
# Out:
#    Rating  Reviews  Size  Installs  Price  day  month  year
# 0     4.1      159  19.0     10000    0.0    7      1  2018
# 1     3.9      967  14.0    500000    0.0   15      1  2018
# 2     4.7    87510   8.7   5000000    0.0    1      8  2018
# 3     4.5   215644  25.0  50000000    0.0    8      6  2018
# 4     4.3      967   2.8    100000    0.0   20      6  2018

# %% [markdown]
# ## Which category has largest numbers of instalation ?

# %%
df1.groupby(['Category'])["Installs"].sum().sort_values(ascending=False)
# Out:
# Category
# GAME                   31544024415
# COMMUNICATION          24152276251
# SOCIAL                 12513867902
# PRODUCTIVITY           12463091369
# TOOLS                  11452771915
# FAMILY                 10041692505
# PHOTOGRAPHY             9721247655
# TRAVEL_AND_LOCAL        6361887146
# VIDEO_PLAYERS           6222002720
# NEWS_AND_MAGAZINES      5393217760
# SHOPPING                2573348785
# ENTERTAINMENT           2455660000
# PERSONALIZATION         2074494782
# BOOKS_AND_REFERENCE     1916469576
# SPORTS                  1528574498
# HEALTH_AND_FITNESS      1361022512
# BUSINESS                 863664865
# FINANCE                  770348734
# MAPS_AND_NAVIGATION      724281890
# LIFESTYLE                534823539
# EDUCATION                533952000
# WEATHER                  426100520
# FOOD_AND_DRINK           257898751
# DATING                   206536107
# HOUSE_AND_HOME           125212461
# ART_AND_DESIGN           124338100
# ...

# %%
df1.groupby(['Category'])["Installs"].sum().nlargest(10).plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Category'>

# %% [markdown]
# ## How many apps are there on google play store which get 5 ratings ?

# %%
df1['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10835                                     Sya9a Maroc - FR
# 10836                     Fr. Mike Schmitz Audio Teachings
# 10837                               Parkinson Exercices FR
# 10838                        The SCP Foundation DB fr nn5n
# 10839        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10357, dtype: object

# %%
df1[df1['Rating']==5][['App','Rating']].head(5)
# Out:
#                                             App  Rating
# 329                Hojiboy Tojiboyev Life Hacks     5.0
# 612               American Girls Mobile Numbers     5.0
# 615                                Awake Dating     5.0
# 633                       Spine- The dating app     5.0
# 636  Girls Live Talk - Free Text and Video Chat     5.0

# %%
len(df1[df1['Rating']==5])
# Out:
# 271

# %% [markdown]
# # what are the top 5 most installed apps in each popular category ?

# %%
df1.groupby(['App'])["Installs"].sum().nlargest(5)
# Out:
# App
# Subway Surfers                  5000000000
# Google Photos                   4000000000
# Hangouts                        4000000000
# Google Chrome: Fast & Secure    3000000000
# Google Drive                    3000000000
# Name: Installs, dtype: int64

# %%
df1.groupby(['App'])["Installs"].sum().nlargest(5).plot.pie()
# Out:
# <AxesSubplot:ylabel='Installs'>

# %% [markdown]
# ## which category app users are reviewing the most ?

# %%
df1.groupby(['App'])["Reviews"].sum().nlargest()
# Out:
# App
# Instagram             199664676
# Facebook              156286514
# Subway Surfers        138606606
# WhatsApp Messenger    138228988
# Clash of Clans        134667058
# Name: Reviews, dtype: int64

# %%
df1.groupby(['App'])["Reviews"].sum().nlargest().plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='App'>

# %%
df1.groupby(['App'])["Reviews"].sum().nlargest().plot.pie()
# Out:
# <AxesSubplot:ylabel='Reviews'>

# %% [markdown]
# ## which kind of app user are downloading the most free\paid ?

# %%
df1.groupby(['App',"Type","Installs"]).sum()
# Out:
#                                                                 Rating  \
# App                                              Type Installs
# "i DT" Fútbol. Todos Somos Técnicos.             Free 500          0.0
# +Download 4 Instagram Twitter                    Free 1000000      4.5
# - Free Comics - Comic Apps                       Free 10000        3.5
# .R                                               Free 10000        4.5
# /u/app                                           Free 10000        4.7
# ...                                                                ...
# 뽕티비 - 개인방송, 인터넷방송, BJ방송                          Free 100000       0.0
# 💎 I'm rich                                       Paid 10000        3.8
# 💘 WhatsLov: Smileys of love, stickers and GIF    Free 1000000      4.6
# 📏 Smart Ruler ↔️ cm/inch measuring for homework! Free 10000        4.0
# 🔥 Football Wallpapers 4K | Full HD Backgrounds 😍 Free 1000000      4.7
#
# ...

# %%
df1_free=df[df['Type']=="Free"]

# %%
df1_free
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df1_paid=df[df['Type']=="Paid"]

# %%
df1_paid
# Out:
#                                                  App            Category  \
# 234    TurboScan: scan documents and receipts in PDF            BUSINESS
# 235                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 290    TurboScan: scan documents and receipts in PDF            BUSINESS
# 291                   Tiny Scanner Pro: PDF Doc Scan            BUSINESS
# 427                               Puffin Browser Pro       COMMUNICATION
# ...                                              ...                 ...
# 10735                                    FP VoiceBot              FAMILY
# 10760                                Fast Tract Diet  HEALTH_AND_FITNESS
# 10782                        Trine 2: Complete Story                GAME
# 10785                                   sugar, sugar              FAMILY
# 10798                           Word Search Tab 1 FR              FAMILY
#
#        Rating Reviews                Size  Installs  Type   Price  \
# ...

# %%
df1.value_counts('Type').plot(kind="pie",figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='None'>
